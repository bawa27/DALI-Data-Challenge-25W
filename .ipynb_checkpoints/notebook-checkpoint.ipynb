# %% [markdown]
# # Aryan Bawa's Dalilab Dev Project!

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('Barnacles/img1.png')
plt.imshow(image)
#
# # Convert to HSV color space for better color segmentation
# hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
#
# # Define range for green color (adjust based on your images)
# lower_green = np.array([0, 150, 45])
# upper_green = np.array([170, 255, 120])
#
# # Convert the BGR color values to HSV color values
# lower_green = cv2.cvtColor(np.uint8([[lower_green]]), cv2.COLOR_BGR2HSV)[0][0]
# upper_green = cv2.cvtColor(np.uint8([[upper_green]]), cv2.COLOR_BGR2HSV)[100][100]
#
# print('Lower green:', lower_green, 'Upper green:', upper_green)
#
# # Create a mask for the green frame
# mask = cv2.inRange(hsv, lower_green, upper_green)
#
# plt.imshow(mask)
